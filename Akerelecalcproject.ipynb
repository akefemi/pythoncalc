# %%
# A python-based Calculator script

# store calcutions in a list
history = []

# calculator function
def Calc():
    
    features = """ This calculator can carry out the following operations:
    1. Multiplication: please specify 'M' or 1
    2. Addition: please specify 'A' or 2
    3. Division: please specify 'D' or 3
    4. Subtraction: please specify 'S' or 4
    5. Exponential: please specify 'E' or 5
    6. Square Root: please specify 'Sq' or 6
    7. Floor Division (Quotient): please specify 'Q' or 7
    8. Modulus operation (Remainder): please specify 'R' or 8
    9. Combination of Operations (Multi-Operation): please specify 'Multiple' or 9
    10. Mean of a list: please specify 'Me' or 10
    11. Sum of a list: please specify 'Su' or 11
    12. Median value of a list: please specify 'Md' or 12
    13. Multiplication of a list: please specify 'MuList' or 13
    14. History: please specify 'H' or 14
    """
    print(features)

    
    # recieving user input
    opr = input('specify operation: M or 1, A or 2, D or 3...Kindly check above for operation indicator  ').capitalize()
    
    # Multiplication operation
    if opr == 'M' or opr == '1' or opr == '*' or opr == 'Multiplication':
        print('ready to execute multiplication. provide input values')
        vals = input('specify input values seperated by comma  ')
        valComponents = vals.split(',')
        print(f'you provided  {len(valComponents)} values for computation ')
        numVals = [float(x.strip()) for x in valComponents]
        
        # initialising the variable res, and use in calculation 
        res = 1
        for val in numVals:
            res = res * val 
            
        # storing the final answer
        opr1 = '*' 
        
        # storing the anwser in string format
        ans= opr1.join(str(v) for v in numVals)
        fAns="{0} = {1}".format(str(ans), str(res))
        history.append(fAns)
        print('result is: ',res)
        
        
        
        # returns the calculator back to initial state 
        Calc()
        
    # Addition operation    
    elif opr == 'A' or opr == '2' or opr == '+' or opr == 'Addition':
        print('ready to execute Addition. provide input values')
        vals = input('specify input values seperated by comma  ')
        valComponents = vals.split(',')
        print(f'you provided  {len(valComponents)} values for computation ')
        numVals = [float(x.strip()) for x in valComponents]

        res = sum(numVals) 
        
        # storing the final answer
        opr1 = '+' 
        
        # storing the anwser in string format
        ans= opr1.join(str(v) for v in numVals)
        fAns="{0} = {1}".format(str(ans), str(res))
        history.append(fAns)
        print('result is: ',res)

        
        # returns the calculator back to initial state
        Calc()
        
    # Division operation        
    elif opr == 'D' or opr == '3' or opr == '/' or opr == 'Division':
        print('ready to execute Division. provide input values')
        vals = input('specify input values seperated by comma   ')
        valComponents = vals.split(',')
        numValues = int(len(valComponents))
        print(f'you provided  {numValues} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
            
        # division using a function to perform multiple division    
       
        def calcdiv():
                try:
                    result = numVals[0]
                    for num in numVals[1:] :
                        result /= num
                    return result
                except ZeroDivisionError:
                    print('error, can not divide zero') 
                    Calc()

        divResult = calcdiv()
        
        # storing the final answer
        opr1 = '/' 
        
        # storing the anwser in string format
        ans= opr1.join(str(v) for v in numVals)
        fAns="{0} = {1}".format(str(ans), str(divResult))
        history.append(fAns)
    
        print('result is: ',divResult)        
        calcdiv()
        
        # returns the calculator back to initial state
        Calc()
                      
            
    # Subtraction operation        
    elif opr == 'S' or opr == '4' or opr == '-' or opr == 'Subtraction':
        print('ready to execute Subtraction. provide input values')
        vals = input('specify input values seperated by comma   ')
        valComponents = vals.split(',')
        numValues = int(len(valComponents))
        print(f'you provided  {numValues} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
    
    #Subtraction using a function to perform multiple Subtraction 
        def calcsub():
            try:
                result = numVals[0]
                for num in numVals[1:] :
                    result -= num
                return result
            except subError:
                print('error, invalid input') 
                Calc()

        divResult = calcsub()
        # storing the final answer
        opr1 = '-' 
        
        # storing the anwser in string format
        ans= opr1.join(str(v) for v in numVals)
        fAns="{0} = {1}".format(str(ans), str(divResult))
        history.append(fAns)
        
        print('result is: ',divResult)        
        calcsub()
        
        # returns the calculator back to initial state
        Calc()
        
    # Exponential operation  
    elif opr == 'E' or opr == '5' or opr == '^' or opr == 'Exponential':
        print('ready to find the Exponential of a value. provide values')
        vals1 = input('provide a value' )
        vals2 = input('provide a Exponential value' )
        if ',' in (vals1,vals2):
            print('please provide a single number for exponention')
            Calc()
        else:
            # remove spaces and convert to float
            vals1 = vals1.strip()
            val1 = float(vals1)
            vals2 = vals2.strip()
            val2 = float(vals2)
            expo = val1 ** val2
            
            # storing the final answer
            opr1 = '^' 
        
            # storing the anwser in string format
            fAns="{0} {1} {2} = {3}".format(str(val1), str(opr1), str(val2), str(expo))
            history.append(fAns)

            print('result is: ',expo) 
            
        # returns the calculator back to initial state
        Calc()
            
            
    # Square Root operation  
    elif opr == 'Sq' or opr == '6' or opr == '**' or opr == 'Square Root':
        print('ready to find the Square Root of a value. provide values')
        vals = input('provide a Single value ')
        if ',' in vals:
            print('please provide a single number')
            Calc()
        else:
            # remove spaces and convert to float
            vals = vals.strip()
            val = float(vals)
            sqrt = val ** 0.5
            
            # storing the final answer
            opr1 = '**' 
        
            fAns=("the square root is ", sqrt)
            history.append(fAns)

            print('result is: ',sqrt)  
            
        # returns the calculator back to initial state
        Calc()
            
            
            
    # Floor Division (Quotient) operation  
    elif opr == 'Q' or opr == '7' or opr == '//' or opr == 'Quotient':
        print('ready to find the Floor Division of a value. provide values')
        vals1 = input('provide Dividend value ')
        vals2 = input('provide Divisor value ')
        if ',' in (vals1,vals2):
            print('please provide a single number for Floor Division ')
            Calc()
        else:
            # remove spaces and convert to float
            vals1 = vals1.strip()
            val1 = float(vals1)
            vals2 = vals2.strip()
            val2 = float(vals2)
            quot = val1 // val2
            
            # storing the final answer
            opr1 = '//' 
        
            # storing the anwser in string format
            fAns="{0} {1} {2} = {3}".format(str(val1), str(opr1), str(val2), str(quot))
            history.append(fAns)

            print('result is: ',quot)  
            
        # returns the calculator back to initial state
        Calc()
            
            
    # Modulus operation (Remainder) operation  
    elif opr == 'R' or opr == '8' or opr == '%' or opr == 'Remainder':
        print('ready to find the Remainder of a value. provide values')
        vals1 = input('provide Dividend value ')
        vals2 = input('provide Divisor value ')
        if ',' in (vals1,vals2):
            print('please provide a single number for Floor Division ')
            Calc()
        else:
            # remove spaces and convert to float
            vals1 = vals1.strip()
            val1 = float(vals1)
            vals2 = vals2.strip()
            val2 = float(vals2)
            remd = val1 % val2
            
            # storing the final answer
            opr1 = '%' 
        
            # storing the anwser in string format
            fAns="{0} {1} {2} = {3}".format(str(val1), str(opr1), str(val2), str(remd))
            history.append(fAns)

            print('result is: ',remd)   
            
        # returns the calculator back to initial state
        Calc()
            
            
    # Mean of a list 
    elif opr == 'Me' or opr == '9' or opr == 'Mean':
        print('ready to find the Mean of a values. provide values')
        vals = input('specify input values seperated by comma   ')
        valComponents = vals.split(',')
        numValues = int(len(valComponents))
        print(f'you provided  {numValues} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
        mean = (sum(numVals) / numValues )
        
        # storing the final answer
        fAns=("the mean is ", mean)
        history.append(fAns)
        
        print('result is: ',mean)
        
        # returns the calculator back to initial state
        Calc()
        
        
    # Median of a list 
    elif opr == 'Md' or opr == '10' or opr == 'Median':
        print('ready to find the Median of a values. provide values')
        vals = input('specify input values seperated by comma   ')
        valComponents = vals.split(',')
        numValues = int(len(valComponents))
        print(f'you provided  {numValues} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
        sortVals = sorted(numVals)
        #print(sortVals)
        if numValues % 2 == 0:
            mid1 =sortVals[numValues // 2 - 1]
            mid2 =sortVals[numValues // 2]
            median = (mid1 + mid2) / 2
            
            print('result is: ',median)
            

        else:
            median = sortVals[numValues // 2]
            
            print('result is: ',median)
            
        # storing the final answer
        fAns=("the median is ", median)
        history.append(fAns)
        
            
        # returns the calculator back to initial state
        Calc()
            
            
    #history of calculations
    elif opr == 'H' or opr == '11' or opr == '#' or opr == 'History':
        if len(history) ==0:
            print("No past calculations to show")
        else:
            with open('history.txt', 'w') as file:
                file.write(str(history))
    
            with open('history.txt', 'r') as file:
                stdHistory = eval(file.read())
    
        
        print('here are your stored values', stdHistory)
            
        
        
    else:
        print('operation unknown')
        Calc()

# %%
Calc()
# Out:
#  This calculator can carry out the following operations:
#     1. Multiplication: please specify 'M' or 1
#     2. Addition: please specify 'A' or 2
#     3. Division: please specify 'D' or 3
#     4. Subtraction: please specify 'S' or 4
#     5. Exponential: please specify 'E' or 5
#     6. Square Root: please specify 'Sq' or 6
#     7. Floor Division (Quotient): please specify 'Q' or 7
#     8. Modulus operation (Remainder): please specify 'R' or 8
#     9. Combination of Operations (Multi-Operation): please specify 'Multiple' or 9
#     10. Mean of a list: please specify 'Me' or 10
#     11. Sum of a list: please specify 'Su' or 11
#     12. Median value of a list: please specify 'Md' or 12
#     13. Multiplication of a list: please specify 'MuList' or 13
#     14. History: please specify 'H' or 14
#
# specify operation: M or 1, A or 2, D or 3...Kindly check above for operation indicator  5
# ready to find the Exponential of a value. provide values
# provide a value4
# ...
